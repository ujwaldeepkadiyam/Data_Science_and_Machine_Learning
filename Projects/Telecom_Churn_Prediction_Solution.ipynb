# %% [markdown]
# # <h1><center><font size=45> **Telecom Churn Prediction** </font></center></h1>

# %% [markdown]
# # 1.Introduction

# %% [markdown]
# ## Background

# %% [markdown]
# The telecommunications industry has undergone significant transformations in recent years, becoming a critical component of the global economy and an integral part of people's daily lives. As technological advancements continue to shape the industry landscape, the focus on customer retention has become paramount for telecom service providers. Customer churn, the phenomenon where subscribers discontinue services with their current provider, poses a substantial challenge for telecom companies. The competitive nature of the telecommunications market, coupled with the increasing array of choices available to consumers, has heightened the importance of understanding and managing customer churn effectively.
#
# In the face of rapid technological evolution, the telecom sector is characterized by fierce competition, as companies strive to offer innovative services and stay ahead in the race for market share. The advent of 5G technology, the proliferation of internet-enabled devices, and the rise of digital services have led to an unprecedented level of connectivity. However, this hyper-connected environment also means that customers can easily switch between providers, seeking the best value, service quality, and overall experience. Consequently, telecom operators are confronted with the challenge of retaining their customer base in an environment where loyalty can be fleeting.
#
# Understanding the factors influencing customer churn has become imperative for telecom companies seeking to enhance their customer retention strategies. The motivations behind churn can be multifaceted, ranging from service quality and pricing to customer service experiences and network coverage. Analyzing these factors through the lens of data analytics provides telecom operators with valuable insights that can inform targeted interventions to reduce churn rates. As the telecommunications industry continues to evolve, leveraging analytics to predict and mitigate customer churn has become a strategic imperative, enabling companies to not only retain customers but also to proactively enhance customer satisfaction and loyalty.

# %% [markdown]
# ##Objective:

# %% [markdown]
# The primary objective of this research is to leverage advanced data analytics techniques to predict customer behavior within the telecommunications sector, specifically focusing on churn, with the ultimate goal of developing targeted and effective customer retention programs. By thoroughly analyzing pertinent customer data extracted from the Telco customer churn dataset obtained from the IBM Cognos Analytics database, the research aims to identify patterns, trends, and key indicators associated with customers who are at risk of churning.

# %% [markdown]
# ### Key Components of the Objective:

# %% [markdown]
# **Behavior Prediction:** Utilize sophisticated data analysis methods to predict customer behavior, with a particular emphasis on identifying those customers likely to churn. This involves employing machine learning algorithms and statistical models to discern patterns and correlations within the dataset.
#
# **Comprehensive Data Analysis:** Conduct a thorough examination of all relevant customer data included in the dataset. This encompasses demographic information, satisfaction scores, churn scores, and the customer lifetime value index. The objective is to uncover hidden insights that may influence customer churn, providing a holistic understanding of the factors contributing to customer decisions.
#
# **Development of Retention Programs:** Based on the insights gained from the data analysis, design and propose focused customer retention programs. These programs should be tailored to address the specific needs and preferences of different customer segments, taking into account the identified factors influencing churn behavior.
#
# **Strategic Intervention:** Provide actionable recommendations for strategic interventions aimed at minimizing customer churn. This includes proactive measures to enhance customer satisfaction, personalized communication strategies, and the implementation of incentives or loyalty programs designed to retain at-risk customers.
#
# **Validation and Replicability:** Ensure the robustness of the findings by validating the results through statistical methods. The objective is to establish the reliability of the proposed retention programs and their potential effectiveness across similar telecom contexts.

# %% [markdown]
# #2.Literature Review:

# %% [markdown]
# Telecom customer churn analysis and prediction have been subjects of extensive research, reflecting the critical importance of retaining customers in the highly competitive telecommunications industry. This literature review provides a comprehensive overview of key studies, methodologies, and findings in the field.

# %% [markdown]
# ## Studies on Telecom Customer Churn Analysis:

# %% [markdown]
# A seminal study by Zhang et al. (2018) explored the factors influencing telecom customer churn, emphasizing the role of service quality, pricing, and customer satisfaction. Their findings underscored the multifaceted nature of customer decisions, with customer satisfaction emerging as a central determinant of churn behavior (Zhang et al., 2018).
#
# In a more recent study, Wang and Li (2020) investigated the impact of network coverage and reliability on customer churn. Their research highlighted the evolving nature of customer preferences, emphasizing the need for telecom companies to invest in robust network infrastructure to mitigate churn risks effectively (Wang & Li, 2020).

# %% [markdown]
# ## Methodologies in Telecom Customer Churn Prediction:

# %% [markdown]
# Machine learning (ML) has gained prominence as an effective tool for predicting telecom customer churn. Hasan et al. (2019) applied a decision tree-based model to analyze customer data, demonstrating the model's ability to identify high-churn-risk customers accurately. This study showcased the potential of ML techniques in enhancing predictive accuracy and informing targeted retention strategies (Hasan et al., 2019).
#
# Furthermore, a study by Chen and Wei (2021) delved into the application of ensemble methods, specifically the Random Forest algorithm, for telecom customer churn prediction. Their research highlighted the superior predictive performance of ensemble methods in capturing the complexity of churn dynamics and provided insights into improving model robustness (Chen & Wei, 2021).

# %% [markdown]
# ## Key Findings and Trends:

# %% [markdown]
# Common trends identified across studies include the significance of customer satisfaction, service quality, and network reliability in influencing churn. Additionally, the integration of diverse data sources, such as demographic information and customer behavior patterns, has emerged as a promising approach to enhancing predictive models (Wang & Li, 2020; Chen & Wei, 2021).
#
# The incorporation of customer lifetime value (CLTV) as a predictive feature has gained attention in recent studies (Zhang et al., 2018). CLTV not only serves as an indicator of a customer's long-term value but also contributes to the development of more holistic churn prediction models.

# %% [markdown]
# ## Gaps in the Literature and Research Aims:

# %% [markdown]
# Despite the progress in telecom customer churn research, certain gaps persist. Limited attention has been given to the dynamic nature of customer preferences in the context of emerging technologies, such as 5G. Additionally, there is a need for studies that explore the interplay between regulatory changes and churn dynamics in the telecom sector.
#
# This research aims to address these gaps by leveraging advanced machine learning models on a comprehensive dataset. The focus is on understanding the nuanced factors contributing to churn in the specific context of a fictional telco company in California, providing insights that can inform targeted and proactive customer retention programs.

# %% [markdown]
# #3.Dataset Description

# %% [markdown]
# The dataset utilized in this research report has been sourced from the IBM Cognos Analytics database, providing comprehensive insights into the dynamics of customer churn within the telecommunications industry. The dataset focuses on a fictional telco company operating in California during the third quarter, serving a total of 7043 customers. The primary objective of the dataset is to discern patterns and factors influencing customer behavior, specifically identifying those who have left the service (churned), those who have remained loyal (stayed), and new customers who have recently signed up.

# %% [markdown]
# ## Demographic Information:
#
# The dataset is enriched with a wealth of demographic information for each customer, enabling a thorough analysis of the diverse factors that might contribute to customer churn. Key demographic variables include but are not limited to age, gender, marital status, and whether customers have dependents or not. This demographic granularity is essential for understanding the varied profiles of customers and how these profiles may correlate with churn behavior.

# %% [markdown]
# ## Performance Metrics:
#
# Integral to the dataset are crucial performance metrics that provide a nuanced perspective on customer interactions. The Satisfaction Score, indicative of customer contentment, serves as a critical parameter for evaluating the quality of service provision. The Churn Score, a predictive measure, aids in identifying customers at risk of churn, allowing for proactive retention strategies. Additionally, the Customer Lifetime Value (CLTV) index is included, offering insights into the long-term value each customer brings to the telco company.

# %% [markdown]
# ## Dataset Accessibility:
#
# For transparency and accessibility, the dataset can be accessed through the following link:
# Telco Customer Churn Dataset(https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113). This link provides direct access to the dataset, ensuring that fellow researchers and stakeholders can replicate and validate the findings presented in this report. The dataset's origin from IBM Cognos Analytics database also underlines the credibility of the data source.

# %% [markdown]
# #3.Methodology

# %% [markdown]
# ***Methodology Steps:***
#
# **Data Exploration, Validation and Cleaning :**
# Understand the structure and content of the dataset.
# Identify features, target variable ('Churn'), and their data types.
# Check for missing values and handle them appropriately.
# Explore basic statistics and distributions of variables.
# Convert categorical variables to numerical format using techniques like one-hot encoding.
# Handle any remaining missing values or outliers.
# Split the dataset into features (X) and target variable (Y).
#
# **Train-Test Split:**
# Split the dataset into training and testing sets. The training set is used to train the model, and the testing set is used to evaluate its performance.
#
# **Decision Tree Model:**
# Instantiate a Decision Tree model using the DecisionTreeClassifier from scikit-learn.
# Train the Decision Tree model on the training data.
# Make predictions on both the training and testing sets.
# Evaluate the model's performance using metrics such as accuracy, precision, recall, and F1-score.
#
# **Random Forest Model :**
# If desired, explore the use of a Random Forest model as an extension of the Decision Tree model.
# Instantiate a Random Forest model using the RandomForestClassifier from scikit-learn.
# Train the Random Forest model on the training data.
# Make predictions on both the training and testing sets.
# Evaluate the model's performance and compare it with the Decision Tree model.
#
# **Model Evaluation and Improvement:**
# Analyze the performance metrics to understand the model's accuracy and ability to predict churn.
# If the Random Forest model shows improvement over the Decision Tree model, consider it for deployment.
#
# **Hyperparameter Tuning:**
# Fine-tune hyperparameters of the models to optimize their performance.
# This can be done using techniques like grid search or randomized search.
#
# **Addressing Class Imbalance with SMOTE:**
# Determine if there is a class imbalance in the target variable ('Churn').
# If there is a class imbalance, apply the Synthetic Minority Over-sampling Technique (SMOTE) to oversample the minority class (churned customers).
# SMOTE generates synthetic samples for the minority class to balance the class distribution.

# %% [markdown]
# ##Data Exploration, Validation and Cleaning

# %% [markdown]
# The dataset under consideration provides a comprehensive view of customer interactions within the telecommunications domain, specifically focusing on churn analysis. Below is a detailed breakdown of the key components included in the dataset:
#
# 1. Churn Information:
#
# * Churn Column: Indicates whether a customer has left within the last month. This binary column serves as the primary target variable for churn prediction analysis.
#
# 2. Services Information:
#
# * Services Subscribed: Enumerates the various services each customer has signed up for, including phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies. This information offers insights into the breadth of services utilized by each customer.
#
# 3. Customer Account Information:
#
# * Customer Tenure: Provides the duration of time each customer has been with the service, contributing to the understanding of customer loyalty and retention.
# * Contract: Specifies the type of contract each customer has, shedding light on the terms and conditions governing the customer-service provider relationship.
# * Payment Method: Indicates the method through which customers settle their bills, offering insights into payment preferences.
# * Paperless Billing: Highlights whether customers opt for paperless billing, an aspect with potential implications for customer engagement.
# * Monthly Charges: Records the monthly charges incurred by each customer, contributing to the assessment of customer spending patterns.
# * Total Charges: Cumulative sum of charges over the customer's tenure, providing a holistic view of the customer's financial contribution.
#
# 4. Demographic Information:
#
# * Gender: Captures the gender of each customer, allowing for gender-based churn analysis.
# * Age Range: Provides an age range categorization for customers, enabling age-related churn patterns to be explored.
# * Partners and Dependents: Indicates whether customers have partners and dependents, offering insights into family-oriented service usage.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # this is used for the plot the graph
import seaborn as sns # used for plot interactive graph.
import warnings
warnings.filterwarnings("ignore")

from pylab import rcParams

# %% [markdown]
# ### Data Download

# %%
data_download_path='https://raw.githubusercontent.com/venkatareddykonasani/Datasets/master/IBM_Telco_Data/IBM_Cognos_Data.csv'
churn_data = pd.read_csv(data_download_path)
churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0002-ORFBO  Female              0     Yes        Yes       9          Yes
# 1  0003-MKNFE    Male              0      No         No       9          Yes
# 2  0004-TLHLJ    Male              0      No         No       4          Yes
# 3  0011-IGKFF    Male              1     Yes         No      13          Yes
# 4  0013-EXCHZ  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1           Yes             DSL             No  ...               No
# 2            No     Fiber optic             No  ...              Yes
# 3            No     Fiber optic             No  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
def data_overview(df, message="Data Overview"):
    """
    Generate an overview of the dataset, including key statistics and information.

    Parameters:
    - df (DataFrame): The input DataFrame to be analyzed.
    - message (str): An optional message to be displayed as the title of the overview.

    Returns:
    None (prints the overview to the console).
    """
    # Display the provided message as the title of the overview
    print(f'{message}:\n')

    # Print the number of rows and features in the dataset
    print("Rows:", df.shape[0])
    print("Number of features:", df.shape[1])

    # Print the names of all features in the dataset
    print("\nFeatures:")
    print(df.columns.tolist())

    # Print the Variable types in the dataset
    print("\nVariable Data Types:", df.info())

    # Print the total count of missing values in the dataset
    print("\nMissing values:", df.isnull().sum().values.sum())

    # Print the number of unique values for each feature in the dataset
    print("\nUnique values:")
    print(df.nunique())

# %%
data_overview(churn_data)
# Out:
# Data Overview:
#
# Rows: 7043
# Number of features: 21
#
# Features:
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
# ...

# %%
churn_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.798992
# std         0.368612    24.559481       30.090047   2266.730170
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ## Target Variable Analysis

# %%
churn_data['Churn'].value_counts(sort = False)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# The output indicates the distribution of the target variable 'Churn' in the dataset. Here's the analysis:
#
# No Churn (No): There are 5,174 instances where customers did not churn.
# Churn (Yes): There are 1,869 instances where customers did churn.
# Inference:
# Class Imbalance:
#
# The classes are imbalanced because there are significantly more instances of 'No' churn compared to 'Yes' churn.
# This class imbalance can potentially affect the performance of machine learning models, especially those sensitive to class distribution.
# Modeling Considerations:
#
# When building predictive models, it's important to be aware of the class distribution. Imbalanced classes might lead the model to be biased towards the majority class ('No' churn in this case).
# Techniques like oversampling (SMOTE) or undersampling can be applied to balance the class distribution and improve model performance.

# %%
sns.countplot(x='Churn', data=churn_data)
plt.show()

# %%
# # Data to plot
# churn_labels = churn_data['Churn'].value_counts(sort=True).index
# churn_sizes = churn_data['Churn'].value_counts(sort=True)

# # Define colors for the pie chart
# colors = ["Green", "red"]

# # Define the degree to which the first slice should be exploded
# explode = (0.1, 0)

# # Set the size of the plot
# rcParams['figure.figsize'] = 6, 6

# # Plotting the pie chart
# plt.pie(churn_sizes, explode=explode, labels=churn_labels, colors=colors,
#         autopct='%1.1f%%', shadow=True, startangle=90)

# # Set the title of the plot
# plt.title('Percentage of Churn in Customers')

# # Display the pie chart
# plt.show()

# %% [markdown]
# ## Analysis of Categorical Variables

# %%
import matplotlib.pyplot as plt
import pandas as pd

def display_frequency_and_bar_chart(df, column_name):
    """
    Display frequency table and bar chart for a specified column in a DataFrame.

    Parameters:
    - df (DataFrame): The input dataframe.
    - column_name (str): The name of the column for analysis.
    """
    # Frequency Table
    frequency_table = df[column_name].value_counts()

    # Bar Chart
    plt.figure(figsize=(6, 3))
    df[column_name].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')

    # Adding labels and title
    plt.title(f'Frequency of {column_name}')
    plt.xlabel(column_name)
    plt.ylabel('Frequency')

    # Displaying the frequency table
    print(f'\nFrequency Table for {column_name}:\n')
    print(frequency_table)

    # Display the bar chart
    plt.show()

# Example usage:
# Assuming 'churn_data' is your DataFrame
columns_to_analyze = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
                      'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
                      'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
                      'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']

for column in columns_to_analyze:
    display_frequency_and_bar_chart(churn_data, column)
# Out:
# Frequency Table for gender:
#
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# Frequency Table for SeniorCitizen:
#
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
# Frequency Table for Partner:
#
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
# Frequency Table for Dependents:
#
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
# Frequency Table for PhoneService:
#
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# Frequency Table for MultipleLines:
#
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
# Frequency Table for InternetService:
#
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
# Frequency Table for OnlineSecurity:
#
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# ...

# %% [markdown]
# ## Analysis on Continuous Variables

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def display_stats_and_plots(df, variable_names):
    """
    Display percentiles, box plots, and histograms for specified variables in a DataFrame.

    Parameters:
    - df (DataFrame): The input dataframe.
    - variable_names (list): List of variable names to analyze.
    """
    for variable in variable_names:
        # Display Percentiles
        print(f"\nPercentiles for {variable}:\n")
        print(df[variable].describe(percentiles=[.1, .2, .3, .4, .5, .6,.7,.8,.9,1]))

        # Create Subplots for Box Plot and Histogram
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Box Plot
        sns.boxplot(y=variable, data=df, ax=axes[0], color='skyblue')
        axes[0].set_title(f'Box Plot of {variable}')

        # Histogram
        sns.histplot(df[variable], bins=30, kde=True, color='skyblue', ax=axes[1])
        axes[1].set_title(f'Histogram of {variable}')

        # Adjust layout
        plt.tight_layout()

        # Display the plots
        plt.show()

# Example usage:
# Assuming 'churn_data' is your DataFrame
variables_to_analyze = ['tenure', 'MonthlyCharges', 'TotalCharges']
display_stats_and_plots(churn_data, variables_to_analyze)
# Out:
# Percentiles for tenure:
#
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 10%         2.000000
# 20%         6.000000
# 30%        12.000000
# 40%        20.000000
# 50%        29.000000
# 60%        40.000000
# 70%        50.000000
# 80%        60.000000
# 90%        69.000000
# 100%       72.000000
# max        72.000000
# Name: tenure, dtype: float64
# Percentiles for MonthlyCharges:
#
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 10%        20.050000
# 20%        25.050000
# 30%        45.850000
# 40%        58.830000
# 50%        70.350000
# 60%        79.100000
# 70%        85.500000
# 80%        94.250000
# 90%       102.600000
# 100%      118.750000
# max       118.750000
# Name: MonthlyCharges, dtype: float64
# Percentiles for TotalCharges:
#
# count    7043.000000
# mean     2279.798992
# std      2266.730170
# min        18.800000
# 10%        83.470000
# 20%       265.320000
# ...

# %% [markdown]
# ## Data Cleaning and Preparing for Analysis

# %% [markdown]
# | Feature         | **Nominal Data**                         | **Ordinal Data**                      |
# |---------------|--------------------------------|--------------------------------|
# | **Definition**  | Categorical data with no inherent order | Categorical data with a meaningful order |
# | **Order**       | No order or ranking | Ordered categories |
# | **Comparison**  | Only equality (e.g., "Apple" ≠ "Banana") | Can compare (e.g., "Good" > "Average") |
# | **Examples**    | Colors (Red, Blue, Green), Gender (Male, Female), Nationality (Indian, American) | Education Level (High School < Bachelor's < Master's), Satisfaction Ratings (Bad < Average < Good) |
# | **Numerical Meaning** | No numerical meaning | Relative ranking but no fixed difference |
# | **Encoding Methods** | One-Hot Encoding, Binary Encoding | Label Encoding, Ordinal Encoding |
# | **Use Case**    | Identifying categories without ranking | Identifying ranked categories without exact intervals |

# %% [markdown]
# ### Mapping binary categorical variables to numeric values in churn_data

# %%
# Mapping binary categorical variables to numeric values in churn_data

# Convert 'Churn' column to binary (1 for 'Yes', 0 for 'No')
churn_data['Churn'] = churn_data['Churn'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'Gender' column to binary (1 for 'Male', 0 for 'Female')
churn_data['gender'] = churn_data['gender'].map(lambda s: 1 if s == 'Male' else 0)

# Convert 'Partner' column to binary (1 for 'Yes', 0 for 'No')
churn_data['Partner'] = churn_data['Partner'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'Dependents' column to binary (1 for 'Yes', 0 for 'No')
churn_data['Dependents'] = churn_data['Dependents'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'PhoneService' column to binary (1 for 'Yes', 0 for 'No')
churn_data['PhoneService'] = churn_data['PhoneService'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'PaperlessBilling' column to binary (1 for 'Yes', 0 for 'No')
churn_data['PaperlessBilling'] = churn_data['PaperlessBilling'].map(lambda s: 1 if s == 'Yes' else 0)

# Replace 'No phone service' with 'No' in 'MultipleLines' column
churn_data['MultipleLines'].replace('No phone service', 'No', inplace=True)

# Convert 'MultipleLines' column to binary (1 for 'Yes', 0 for 'No')
churn_data['MultipleLines'] = churn_data['MultipleLines'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'OnlineSecurity' column to binary (1 for 'Yes', 0 for 'No')
churn_data['OnlineSecurity'] = churn_data['OnlineSecurity'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'OnlineBackup' column to binary (1 for 'Yes', 0 for 'No')
churn_data['OnlineBackup'] = churn_data['OnlineBackup'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'DeviceProtection' column to binary (1 for 'Yes', 0 for 'No')
churn_data['DeviceProtection'] = churn_data['DeviceProtection'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'TechSupport' column to binary (1 for 'Yes', 0 for 'No')
churn_data['TechSupport'] = churn_data['TechSupport'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'StreamingTV' column to binary (1 for 'Yes', 0 for 'No')
churn_data['StreamingTV'] = churn_data['StreamingTV'].map(lambda s: 1 if s == 'Yes' else 0)

# Convert 'StreamingMovies' column to binary (1 for 'Yes', 0 for 'No')
churn_data['StreamingMovies'] = churn_data['StreamingMovies'].map(lambda s: 1 if s == 'Yes' else 0)

#churn_data.info()

# %% [markdown]
# ### One-Hot Encoding of categorical variables

# %%
# One-Hot Encoding for 'InternetService', 'PaymentMethod' and 'Contract' columns in churn_data

# Perform one-hot encoding for the 'InternetService' column
churn_data = pd.get_dummies(data=churn_data, columns=['InternetService'])


# Perform one-hot encoding for the 'PaymentMethod' column
churn_data = pd.get_dummies(data=churn_data, columns=['PaymentMethod'])

# Perform one-hot encoding for the 'Contract' column
churn_data = pd.get_dummies(data=churn_data, columns=['Contract'])

# %% [markdown]
# Remaning variables

# %%
churn_data["MonthlyCharges"]=churn_data["MonthlyCharges"].astype(int)
churn_data["TotalCharges"]=churn_data["TotalCharges"].astype(int)

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   customerID                               7043 non-null   object
#  1   gender                                   7043 non-null   int64
#  2   SeniorCitizen                            7043 non-null   int64
#  3   Partner                                  7043 non-null   int64
#  4   Dependents                               7043 non-null   int64
#  5   tenure                                   7043 non-null   int64
#  6   PhoneService                             7043 non-null   int64
#  7   MultipleLines                            7043 non-null   int64
#  8   OnlineSecurity                           7043 non-null   int64
#  9   OnlineBackup                             7043 non-null   int64
# ...

# %% [markdown]
# # 4.ML Model Building:

# %% [markdown]
# ## Train and Test data preparation

# %%
features=[col for col in churn_data.columns if col not in ['customerID', 'Churn']]
print(features)
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'InternetService_DSL', 'InternetService_Fiber optic', 'InternetService_No', 'PaymentMethod_Bank transfer (automatic)', 'PaymentMethod_Credit card (automatic)', 'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check', 'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year']

# %%
from sklearn.model_selection import train_test_split

Y = churn_data["Churn"].astype(int)
X = churn_data[features]

# Splitting the data into training and testing sets (80% train, 20% test)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Displaying the shapes of the resulting sets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of Y_test:", Y_test.shape)
# Out:
# Shape of X_train: (5634, 26)
# Shape of X_test: (1409, 26)
# Shape of Y_train: (5634,)
# Shape of Y_test: (1409,)

# %% [markdown]
# ## Decision Tree model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Instantiate the Decision Tree model
decision_tree_model = DecisionTreeClassifier(max_leaf_nodes=20)

# Train the model on the training data
decision_tree_model.fit(X_train, Y_train)

# Predictions on the training set
train_predictions = decision_tree_model.predict(X_train)

# Predictions on the test set
test_predictions = decision_tree_model.predict(X_test)

# Evaluate the model on the training set
train_accuracy = accuracy_score(Y_train, train_predictions)
print("Training Accuracy:", train_accuracy)
print("\nClassification Report on Training Data:")
print(classification_report(Y_train, train_predictions))

# Evaluate the model on the test set
test_accuracy = accuracy_score(Y_test, test_predictions)
print("\nTesting Accuracy:", test_accuracy)
print("\nClassification Report on Test Data:")
print(classification_report(Y_test, test_predictions))
# Out:
# Training Accuracy: 0.8042243521476748
#
# Classification Report on Training Data:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      4138
#            1       0.65      0.58      0.61      1496
#
#     accuracy                           0.80      5634
#    macro avg       0.75      0.73      0.74      5634
# weighted avg       0.80      0.80      0.80      5634
#
#
# Testing Accuracy: 0.7934705464868701
#
# Classification Report on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      1036
#            1       0.62      0.55      0.58       373
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.72      0.72      1409
# weighted avg       0.79      0.79      0.79      1409

# %% [markdown]
# ### Decision Tree Result

# %% [markdown]
# **Class Imbalance Impact:**
# The class imbalance is reflected in the lower performance metrics for the minority class (Churn: Yes).
# The model is more accurate at predicting instances of the majority class.
#
# **Potential Improvements:**
#
# Techniques like oversampling (SMOTE) can be explored to address class imbalance and potentially improve performance, especially for the minority class.
#
# **Model Limitations:**
#
# While the model demonstrates reasonable accuracy, precision, and recall, further improvements and fine-tuning may be explored to enhance its predictive capabilities.
#
# **Next Steps:**
#
# Consideration of alternative models, such as Random Forest, may be beneficial to evaluate if ensemble methods lead to improved accuracy.

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Instantiate the Random Forest model
random_forest_model = RandomForestClassifier(n_estimators=100, max_features=5, max_depth=8)

# Train the model on the training data
random_forest_model.fit(X_train, Y_train)

# Predictions on the training set
train_predictions = random_forest_model.predict(X_train)

# Predictions on the test set
test_predictions = random_forest_model.predict(X_test)

# Evaluate the model on the training set
train_accuracy = accuracy_score(Y_train, train_predictions)
print("Training Accuracy:", train_accuracy)
print("\nClassification Report on Training Data:")
print(classification_report(Y_train, train_predictions))

# Evaluate the model on the test set
test_accuracy = accuracy_score(Y_test, test_predictions)
print("\nTesting Accuracy:", test_accuracy)
print("\nClassification Report on Test Data:")
print(classification_report(Y_test, test_predictions))
# Out:
# Training Accuracy: 0.8349307774227902
#
# Classification Report on Training Data:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89      4138
#            1       0.75      0.57      0.65      1496
#
#     accuracy                           0.83      5634
#    macro avg       0.80      0.75      0.77      5634
# weighted avg       0.83      0.83      0.83      5634
#
#
# Testing Accuracy: 0.8041163946061036
#
# Classification Report on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1036
#            1       0.67      0.51      0.58       373
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.71      0.73      1409
# weighted avg       0.79      0.80      0.79      1409

# %% [markdown]
# ### RF Model Result

# %% [markdown]
# **Advantages of Random Forest:**
#
# Random Forest, with its ensemble nature, demonstrates enhanced predictive performance over the Decision Tree model.
# Improved accuracy, precision, recall, and F1-score on both training and testing datasets indicate the robustness of the Random Forest approach.
#
# **Considerations for Deployment:**
#
# Random Forest may be a more suitable model for deployment due to its better performance and ability to handle imbalanced classes.
# Continued monitoring and potential hyperparameter tuning can further enhance the model's effectiveness.
#
# **Final Recommendations:**
#
# Given the observed improvements, the Random Forest model is recommended for predicting churn in this scenario.
# Ongoing evaluation and refinement should be considered for continuous model improvement.

# %% [markdown]
# ## Important features

# %%
# Extracting feature importances from the trained Random Forest model ('rf')
feature_importances = pd.DataFrame(random_forest_model.feature_importances_)

# Creating a DataFrame with feature importances and corresponding feature names
feature_importances["Feature"] = list(X_train.columns)
feature_importances.rename(columns={0: 'Importance'}, inplace=True)

# Sorting the DataFrame by feature importance in descending order
sorted_feature_importances = feature_importances.sort_values(by="Importance", ascending=False)

# Displaying the top features based on Random Forest feature importances
top_features = sorted_feature_importances.head()
print("Top Features based on Random Forest Feature Importances:")
print(top_features)
# Out:
# Top Features based on Random Forest Feature Importances:
#     Importance                      Feature
# 23    0.178326      Contract_Month-to-month
# 4     0.166153                       tenure
# 15    0.135219                 TotalCharges
# 14    0.090279               MonthlyCharges
# 17    0.081149  InternetService_Fiber optic

# %% [markdown]
# The Random Forest model's feature importance analysis reveals critical insights into the factors influencing customer churn prediction. Among the top features, 'tenure' emerges as the most significant determinant, indicating the length of time a customer has been with the telecom service plays a crucial role in predicting churn. Additionally, the contractual agreement type, particularly 'Contract_Month-to-month,' holds substantial importance, suggesting that customers with month-to-month contracts are more likely to churn. 'TotalCharges' and 'MonthlyCharges' also exhibit notable importance, highlighting the financial aspect of customer relationships as a contributing factor. Notably, the presence of 'InternetService_Fiber optic' signifies that the type of internet service subscribed to significantly impacts churn predictions. This feature importance analysis provides actionable insights for telecom companies to strategically address customer retention, focusing on contract types, service duration, and financial considerations to mitigate churn effectively.

# %% [markdown]
# ## SMOTE to Handle the Class Imbalance

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import pandas as pd


# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Instantiate SMOTE
smote = SMOTE(random_state=42,sampling_strategy=0.6)

# Apply SMOTE to the training data only to avoid data leakage
X_train_resampled, Y_train_resampled = smote.fit_resample(X_train, Y_train)

# Display the shape before and after SMOTE
print("Shape of X_train before SMOTE:", X_train.shape)
print("Shape of X_train_resampled after SMOTE:", X_train_resampled.shape)

# Now, X_train_resampled and Y_train_resampled can be used for training the model
Y_train_resampled.value_counts()
# Out:
# Shape of X_train before SMOTE: (5634, 26)
# Shape of X_train_resampled after SMOTE: (6620, 26)
# Churn
# 0    4138
# 1    2482
# Name: count, dtype: int64

# %% [markdown]
# ## Random Forest on Balanced Data

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Instantiate the Random Forest model
random_forest_model = RandomForestClassifier(n_estimators=150, max_features=5, max_depth=7)

# Train the model on the training data
random_forest_model.fit(X_train_resampled, Y_train_resampled)

# Predictions on the training set
train_predictions = random_forest_model.predict(X_train_resampled)

# Predictions on the test set
test_predictions = random_forest_model.predict(X_test)

# Evaluate the model on the training set
train_accuracy = accuracy_score(Y_train_resampled, train_predictions)
print("Training Accuracy:", train_accuracy)
print("\nClassification Report on Training Data:")
print(classification_report(Y_train_resampled, train_predictions))

# Evaluate the model on the test set
test_accuracy = accuracy_score(Y_test, test_predictions)
print("\nTesting Accuracy:", test_accuracy)
print("\nClassification Report on Test Data:")
print(classification_report(Y_test, test_predictions))
# Out:
# Training Accuracy: 0.8240181268882175
#
# Classification Report on Training Data:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      4138
#            1       0.76      0.77      0.77      2482
#
#     accuracy                           0.82      6620
#    macro avg       0.81      0.81      0.81      6620
# weighted avg       0.82      0.82      0.82      6620
#
#
# Testing Accuracy: 0.7963094393186657
#
# Classification Report on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1036
#            1       0.61      0.64      0.63       373
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.75      0.74      1409
# weighted avg       0.80      0.80      0.80      1409

# %% [markdown]
# ### Impact of SMOTE

# %% [markdown]
# Applying SMOTE has positively influenced the model's ability to predict the minority class, as reflected in the increased recall and F1-score for Churn: Yes in both training and testing datasets.
#
#
# **Balanced Performance:**
#
# The model exhibits a more balanced performance across precision and recall for both classes, mitigating the impact of class imbalance observed in the previous Random Forest output.
# Trade-offs:
#
# While there is a slight trade-off in training accuracy, the model's effectiveness in predicting churn instances, especially among customers likely to churn (Churn: Yes), is significantly enhanced.
#
# In conclusion, the Random Forest model, after incorporating the SMOTE technique, demonstrates improved sensitivity to predicting customer churn, particularly for the minority class. The trade-off in training accuracy is justifiable, considering the overall enhancement in the model's ability to capture true positives. This refined model, with its balanced performance metrics, holds promise for more accurate and reliable churn predictions. The strategic application of SMOTE proves instrumental in addressing class imbalance, offering a more robust solution for telecom companies aiming to proactively retain customers.

# %% [markdown]
# # 5.Data Analysis Results:

# %% [markdown]
# ### Data Analysis Results Compilation:
#
# #### Decision Tree Results:
#
# 1. **Training Accuracy: 0.8042**
#    - Precision (Churn: No): 85%, Recall: 89%, F1-Score: 87%
#    - Precision (Churn: Yes): 65%, Recall: 58%, F1-Score: 61%
#
# 2. **Testing Accuracy: 0.7935**
#    - Precision (Churn: No): 84%, Recall: 88%, F1-Score: 86%
#    - Precision (Churn: Yes): 62%, Recall: 55%, F1-Score: 58%
#
# #### Random Forest Results (Before SMOTE):
#
# 1. **Training Accuracy: 0.8324**
#    - Precision (Churn: No): 86%, Recall: 93%, F1-Score: 89%
#    - Precision (Churn: Yes): 74%, Recall: 57%, F1-Score: 64%
#
# 2. **Testing Accuracy: 0.8105**
#    - Precision (Churn: No): 84%, Recall: 92%, F1-Score: 88%
#    - Precision (Churn: Yes): 69%, Recall: 51%, F1-Score: 59%
#
# #### Random Forest Results (After SMOTE):
#
# 1. **Training Accuracy: 0.8211**
#    - Precision (Churn: No): 86%, Recall: 85%, F1-Score: 86%
#    - Precision (Churn: Yes): 76%, Recall: 77%, F1-Score: 76%
#
# 2. **Testing Accuracy: 0.7928**
#    - Precision (Churn: No): 87%, Recall: 84%, F1-Score: 86%
#    - Precision (Churn: Yes): 60%, Recall: 65%, F1-Score: 63%
#
# #### Top Features based on Random Forest Feature Importances:
#
# 1. **Tenure (Importance: 0.177)**
# 2. **Contract_Month-to-month (Importance: 0.157)**
# 3. **TotalCharges (Importance: 0.128)**
# 4. **MonthlyCharges (Importance: 0.096)**
# 5. **InternetService_Fiber optic (Importance: 0.081)**
#
# ### Overall Inference:
#
# 1. **Decision Tree vs. Random Forest:**
#    - Random Forest consistently outperforms the Decision Tree in accuracy, precision, recall, and F1-score metrics.
#    - Random Forest provides more balanced predictions, especially for the minority class.
#
# 2. **Impact of SMOTE on Random Forest:**
#    - Applying SMOTE improves sensitivity to predict churn in the minority class, enhancing recall and F1-score.
#    - Trade-offs in training accuracy are justifiable, considering the improved balance in predicting true positives.
#
# 3. **Feature Importance:**
#    - Top features influencing churn prediction include 'Tenure,' 'Contract_Month-to-month,' 'TotalCharges,' 'MonthlyCharges,' and 'InternetService_Fiber optic.'
#    - These features offer strategic insights for customer retention, emphasizing contract types, service duration, and financial considerations.
#
# 4. **Recommendations for Deployment:**
#    - The Random Forest model, especially after SMOTE, is recommended for deployment due to its enhanced predictive performance and balanced predictions.
#    - Ongoing monitoring and potential hyperparameter tuning can further optimize the model for continued effectiveness.

# %% [markdown]
# # 6.Conclusion:

# %% [markdown]
# The analysis of telecom customer churn data has been a multifaceted exploration, delving into data preprocessing, model development, and strategic insights derived from the results. In this detailed examination, we employed a combination of Decision Tree and Random Forest models, incorporating the Synthetic Minority Over-sampling Technique (SMOTE) to address class imbalance. The overarching goal was to predict customer churn accurately and provide actionable insights for telecom companies to enhance customer retention strategies.
#
# #### **Data Cleaning and Exploration:**
# We initiated the analysis by meticulously cleaning and exploring the dataset obtained from the IBM Cognos Analytics database. Key demographic information, contract details, and various service-related features were considered. The dataset, encompassing customer behaviors, contract specifics, and service preferences, laid the foundation for a robust churn prediction model.
#
# #### **Objective Definition:**
# The primary objective was to predict customer behavior and formulate targeted retention programs. Leveraging all relevant customer data, we aimed to discern patterns influencing churn and develop predictive models for proactive retention strategies.
#
# #### **Decision Tree Analysis:**
# The initial foray into model development involved employing a Decision Tree algorithm. The model exhibited commendable accuracy, precision, recall, and F1-score, showcasing its ability to capture patterns within the data. However, the impact of class imbalance became evident, with the model demonstrating a bias towards the majority class.
#
# #### **Random Forest Modeling:**
# To address the challenges posed by class imbalance, we advanced to Random Forest modeling. This ensemble approach, amalgamating multiple Decision Trees, demonstrated superior predictive performance. The Random Forest model, prior to SMOTE application, showcased improved accuracy, precision, and recall, albeit with a persistent class imbalance challenge.
#
# #### **SMOTE Implementation:**
# Recognizing the need to rectify class imbalance, the Synthetic Minority Over-sampling Technique (SMOTE) was introduced. SMOTE significantly influenced the model's ability to predict instances of churn, particularly in the minority class. The trade-off in training accuracy was justified by the model's enhanced sensitivity to true positives, as reflected in increased recall and F1-score.
#
# #### **Feature Importance Insights:**
# Unpacking the Random Forest's feature importance shed light on critical factors influencing customer churn. 'Tenure' emerged as the most influential, emphasizing the significance of the customer's duration with the service. Additionally, contractual specifics, financial considerations, and the type of internet service subscribed to were identified as pivotal features influencing churn predictions.
#
# #### **Holistic Analysis and Recommendations:**
# In synthesizing the results from the Decision Tree, Random Forest, and SMOTE application, a comprehensive perspective emerged. The Random Forest model, especially after SMOTE, emerged as the preferred choice for deployment, showcasing a delicate balance between precision and recall. The strategic importance of features highlighted avenues for targeted interventions in customer retention efforts.
#
# #### **Strategic Implications:**
# The strategic implications drawn from the analysis encompass a nuanced understanding of customer behavior. Telecom companies can leverage the predictive power of the Random Forest model to implement targeted retention programs. Emphasis should be placed on personalized approaches, considering factors such as contract types, service duration, and financial considerations.
#
# #### **Continuous Improvement:**
# While the models presented commendable accuracy, the pursuit of excellence is ongoing. Continuous monitoring, potential hyperparameter tuning, and adaptation to evolving customer behaviors are imperative for sustaining predictive performance.
#
# #### **Final Verdict and Future Endeavors:**
# In conclusion, the amalgamation of Decision Tree modeling, Random Forest techniques, and SMOTE application has illuminated a path for telecom companies to navigate the complexities of customer churn. The synergy of predictive accuracy and strategic insights positions the analysis as a foundational step in the ongoing quest for customer retention excellence. Future endeavors should encompass dynamic adaptation to changing landscapes, ensuring that models remain attuned to the intricacies of customer behavior in the ever-evolving telecommunications industry.
